# %%
import os
import pandas as pd
import numpy as np
import re 

from mlxtend.regressor import StackingRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
os.getcwd()
# Out:
# 'c:\\Users\\dscshap3808\\Documents\\data\\dlwisdom\\mlb'

# %%
mlb_in = pd.read_csv('./mlb_in.csv')
mlb_in.dropna(subset=['SKU', 'name'], inplace=True)
(mlb_in).shape
# Out:
# (82387, 5)

# %%
mlb_in['top'] = mlb_in['name'].str.extract(r'(衣|夹克|衫|服|马甲|恤)').isnull() != True
mlb_in['top'] = mlb_in['top'].astype(int)
mlb_in['sp'] = mlb_in['name'].str.extract(r'(饰品|配饰)').isnull() != True
mlb_in['sp'] = mlb_in['sp'].astype(int)
mlb_in['cap'] = mlb_in['name'].str.extract(r'(.+CAP|帽)').isnull() != True
mlb_in['cap'] = mlb_in['cap'].astype(int)
mlb_in['pack'] = mlb_in['name'].str.extract(r'(.+PACK|包)').isnull() != True
mlb_in['pack'] = mlb_in['pack'].astype(int)

mlb_in['female'] = mlb_in['name'].str.extract(r'(女士)').isnull() != True
mlb_in['female'] = mlb_in['female'].astype(int)
mlb_in['pants'] = mlb_in['name'].str.extract(r'(裤|PANT)').isnull() != True
mlb_in['pants'] = mlb_in['pants'].astype(int)
mlb_in['OVERSIZED'] = mlb_in['name'].str.extract(r'(.+OVERSIZED)').isnull() != True
mlb_in['OVERSIZED'] = mlb_in['OVERSIZED'].astype(int)
 
mlb_in['DAIMAROO'] = mlb_in['name'].str.extract(r'(DAIMAROO)').isnull() != True
mlb_in['DAIMAROO'] = mlb_in['DAIMAROO'].astype(int)
mlb_in['COMFORTABLE'] = mlb_in['name'].str.extract(r'(.+COMFORTABLE)').isnull() != True
mlb_in['COMFORTABLE'] = mlb_in['COMFORTABLE'].astype(int)

mlb_in['tmjl'] = mlb_in['name'].str.extract(r'(天猫精灵)').isnull() != True
mlb_in['tmjl'] = mlb_in['tmjl'].astype(int)
mlb_in['share'] = mlb_in['name'].str.extract(r'(共用)').isnull() != True
mlb_in['share'] = mlb_in['share'].astype(int)
mlb_in['shoe'] = mlb_in['name'].str.extract(r'(鞋)').isnull() != True
mlb_in['shoe'] = mlb_in['shoe'].astype(int)
mlb_in['cup'] = mlb_in['name'].str.extract(r'(杯)').isnull() != True
mlb_in['cup'] = mlb_in['cup'].astype(int)
mlb_in['textile'] = mlb_in['name'].str.extract(r'(纺织品)').isnull() != True
mlb_in['textile'] = mlb_in['textile'].astype(int)

mlb_in['socks'] = mlb_in['name'].str.extract(r'(袜)').isnull() != True
mlb_in['socks'] = mlb_in['socks'].astype(int)

mlb_in['dress'] = mlb_in['name'].str.extract(r'(裙)').isnull() != True
mlb_in['dress'] = mlb_in['dress'].astype(int)
mlb_in['suit'] = mlb_in['name'].str.extract(r'(套装)').isnull() != True
mlb_in['suit'] = mlb_in['suit'].astype(int)
mlb_in['fan'] = mlb_in['name'].str.extract(r'(风扇)').isnull() != True
mlb_in['fan'] = mlb_in['fan'].astype(int)

# %%
mlb_in['else'] = 0
mlb_in.loc[mlb_in.iloc[:,5:].sum(axis = 1) == 0, 'else'] = 1
# mlb_in[mlb_in.iloc[:,5:].sum(axis = 1)  == 0]

# %%
mlb_in['year'] = mlb_in['time'].str.extract(r'(.{4})')
mlb_in['month']= mlb_in['time'].str.extract(r'(?<=/)(\d+)')
mlb_in['date'] = mlb_in['time'].str.extract(r'(?<=/\d/)(\d+)')

# %%
# mlb_quant = pd.DataFrame(
#     mlb_in.groupby([mlb_in['month'], mlb_in['date'], mlb_in['']]).sum()['quant'])
mlb_in_train = pd.DataFrame(mlb_in.groupby(['year','month','date'], as_index = False).sum('quant'))

cols = ['year','month','date']
mlb_in_train['yearmon'] = mlb_in_train[cols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")
mlb_in_train['yearmon'] = pd.to_datetime(mlb_in_train['yearmon'])

# %%
mlb_in_train = mlb_in_train.sort_values(['yearmon'])

# %%
# mlb_in_train[mlb_in_train['month'] == "6"]
mlb_in_train.shape[0]/7
# Out:
# 24.0

# %%
import datetime

# %%
# tests # sunday start
wee = list([1,0,0,1,1,1,1])
wee = wee*24
mlb_in_train['wee'] = wee
mlb_in_train.drop('yearmon', axis = 1)
# Out:
#      year month date    quant  top  sp  cap  pack  female  pants  ...  share  \
# 0    2021     1    1     42.0   21   6    3    13       0      0  ...     23
# 11   2021     1    2  11295.0  147  11    7    11       0     18  ...     27
# 22   2021     1    3  21334.0   24   6    5    11       3     26  ...     10
# 24   2021     1    4  39143.0   96  12   43    12       3      5  ...     31
# 25   2021     1    5   9252.0   37  21   11    12       2      1  ...     45
# ..    ...   ...  ...      ...  ...  ..  ...   ...     ...    ...  ...    ...
# 156  2021     6   17  36348.0   38   4   36     0       0      3  ...      6
# 157  2021     6   18  54433.0  439   7   41     4       0     11  ...     10
# 158  2021     6   19  22149.0   79   7   25     3       1     17  ...     13
# 160  2021     6   20  18994.0   91  12   17     2       2     62  ...     25
# 161  2021     6   21    489.0  168  16   48     6       1     17  ...     33
#
#      shoe  cup  textile  socks  dress  suit  fan  else  wee
# 0       2    0        6      0      0     0    0     0    1
# 11      0    0        5      0      0     0    0     0    0
# 22     49    0        1      0      1     0    0     0    0
# 24      2    0        3      0      1     0    0     0    1
# 25      2    0        4      0      0     0    0     0    1
# ..    ...  ...      ...    ...    ...   ...  ...   ...  ...
# 156    70    0        0      0      3     0    0     0    0
# 157   135    2        0      0      9     0    2     0    1
# 158    91    2        0      0     14     0    0     0    1
# 160   101    8        0      0     15     0    2     0    1
# 161   116    4        0      0     22     0    3     0    1
#
# [168 rows x 24 columns]

# %%
mlb_in_train_1 = mlb_in_train[mlb_in_train['month'] != "6"]
mlb_in_tests_1 = mlb_in_train[mlb_in_train['month'] == "6"]

# %%
mlb_in_train.head()
# Out:
#     year month date    quant  top  sp  cap  pack  female  pants  ...  shoe  \
# 0   2021     1    1     42.0   21   6    3    13       0      0  ...     2
# 11  2021     1    2  11295.0  147  11    7    11       0     18  ...     0
# 22  2021     1    3  21334.0   24   6    5    11       3     26  ...    49
# 24  2021     1    4  39143.0   96  12   43    12       3      5  ...     2
# 25  2021     1    5   9252.0   37  21   11    12       2      1  ...     2
#
#     cup  textile  socks  dress  suit  fan  else    yearmon  wee
# 0     0        6      0      0     0    0     0 2021-01-01    1
# 11    0        5      0      0     0    0     0 2021-01-02    0
# 22    0        1      0      1     0    0     0 2021-01-03    0
# 24    0        3      0      1     0    0     0 2021-01-04    1
# 25    0        4      0      0     0    0     0 2021-01-05    1
#
# [5 rows x 25 columns]

# %% [markdown]
# ---
#
# undone part 624

# %%
mlb_in.columns[[-2,-1,]]
# Out:
# Index(['month', 'date'], dtype='object')

# %%
mlb_in.columns[5:-3]
# Out:
# Index(['top', 'sp', 'cap', 'pack', 'female', 'pants', 'OVERSIZED', 'DAIMAROO',
#        'COMFORTABLE', 'tmjl', 'share', 'shoe', 'cup', 'textile', 'socks',
#        'dress', 'suit', 'fan', 'else'],
#       dtype='object')

# %%
# list(mlb_in.columns[5:])
# list(mlb_in.columns[[2,3]])
mlb_long = mlb_in.melt(
    id_vars = list(mlb_in.columns[[2, -2,-1,]]),value_vars=list(mlb_in.columns[5:-3]))

# %%
mlb_long['variable'].unique()
# Out:
# array(['top', 'sp', 'cap', 'pack', 'female', 'pants', 'OVERSIZED',
#        'DAIMAROO', 'COMFORTABLE', 'tmjl', 'share', 'shoe', 'cup',
#        'textile', 'socks', 'dress', 'suit', 'fan', 'else'], dtype=object)

# %%
# mlb_long

# %%
# mlb_long.drop('value', axis = 1).groupby(['month', 'date','variable']).sum('quant')

# %%
# mlb_long.groupby(
    # ['month','date','variable']).sum()

# %%
# mlb_fin = pd.DataFrame(mlb_fin)

# %%
# mlb_quant .merge(mlb_fin, on=['month', 'date'], how = 'outer')

# %% [markdown]
# ---
# undone part 624 end

# %% [markdown]
# code

# %%
# (mlb_in['code'].str.extract(r'(^[A-Z])').isnull() != True).sum(axis =1)

# %% [markdown]
# ## model

# %%
# mlb_in_train_1
# mlb_in_tests_1
mlb_in_train_tar = mlb_in_train_1.pop('quant')
mlb_in_train_tar = list(mlb_in_train_tar)
mlb_in_train_1 = mlb_in_train_1.drop('yearmon', axis = 1)
mlb_in_train_1['year'] = mlb_in_train_1['year'].astype(int)
mlb_in_train_1['month'] = mlb_in_train_1['month'].astype(int)
mlb_in_train_1['date'] = mlb_in_train_1['date'].astype(int)

mlb_in_tests_1 = mlb_in_tests_1.drop('yearmon', axis = 1)
mlb_in_tests_1['year'] = mlb_in_tests_1['year'].astype(int)
mlb_in_tests_1['month'] = mlb_in_tests_1['month'].astype(int)
mlb_in_tests_1['date'] = mlb_in_tests_1['date'].astype(int)

# %%
from sklearn.linear_model import Ridge, LinearRegression
from sklearn import model_selection
cv_split = model_selection.ShuffleSplit(n_splits = 5, test_size = .2, train_size = .8, random_state = 529)

# %%
alg1 = LinearRegression()
cv_results_1 = model_selection.cross_validate(
    alg1, mlb_in_train_1, mlb_in_train_tar, 
    cv  = cv_split, 
    scoring='neg_mean_absolute_percentage_error')
cv_results_1['test_score'].mean()
# Out:
# -15.700188454108854

# %%
alg2 = Ridge()
cv_results_2 = model_selection.cross_validate(alg2, mlb_in_train_1, mlb_in_train_tar, cv  = cv_split, scoring='neg_mean_absolute_percentage_error')
cv_results_2['test_score'].mean()
# Out:
# -15.815162577517702

# %%
from sklearn.neural_network import MLPRegressor
alg3 = MLPRegressor(
    hidden_layer_sizes = (345, 31, 1), 
    max_iter=1000,verbose=True, 
    activation = 'relu', 
    solver = 'adam', 
    alpha = .05,
    batch_size = 15,
    # momentum = .9,
    learning_rate = 'adaptive')

cv_results_3 = model_selection.cross_validate(
    alg3, mlb_in_train_1, mlb_in_train_tar, 
    cv  = cv_split, 
    scoring='neg_mean_absolute_percentage_error')
cv_results_3['test_score'].mean()
# Out:
# Iteration 1, loss = 2601719321.04825783
# Iteration 2, loss = 2585686840.19755507
# Iteration 3, loss = 2569370254.25047970
# Iteration 4, loss = 2543894775.93331957
# Iteration 5, loss = 2521127443.47089291
# Iteration 6, loss = 2477176688.88135338
# Iteration 7, loss = 2430969016.95170879
# Iteration 8, loss = 2379571789.93371630
# Iteration 9, loss = 2308692585.49478006
# Iteration 10, loss = 2236161676.80604792
# Iteration 11, loss = 2175202850.31364059
# Iteration 12, loss = 2093817238.64541221
# Iteration 13, loss = 2019310945.11945224
# Iteration 14, loss = 1966188709.00198221
# Iteration 15, loss = 1922192438.02109504
# Iteration 16, loss = 1892338493.98472357
# Iteration 17, loss = 1882802641.36081433
# Iteration 18, loss = 1870697671.30116653
# Iteration 19, loss = 1852236839.33605433
# Iteration 20, loss = 1836483654.02431011
# Iteration 21, loss = 1826489416.09533477
# Iteration 22, loss = 1811080377.91293001
# Iteration 23, loss = 1802143336.16510224
# Iteration 24, loss = 1798614378.29835439
# Iteration 25, loss = 1781122711.87402797
# Iteration 26, loss = 1773369701.33181310
# Iteration 27, loss = 1767808533.84254599
# Iteration 28, loss = 1749628929.93193984
# Iteration 29, loss = 1739566466.56852865
# Iteration 30, loss = 1734085130.30598736
# Iteration 31, loss = 1720394555.66238713
# Iteration 32, loss = 1709470924.33907461
# Iteration 33, loss = 1699558929.99881363
# Iteration 34, loss = 1695781972.07164884
# Iteration 35, loss = 1676817405.64252067
# Iteration 36, loss = 1674738700.42882967
# Iteration 37, loss = 1664666302.72385716
# Iteration 38, loss = 1647651112.23534107
# Iteration 39, loss = 1640185968.01031995
# Iteration 40, loss = 1630901261.76015472
# Iteration 41, loss = 1617844713.23795819
# Iteration 42, loss = 1606699462.91920185
# Iteration 43, loss = 1598171704.14982295
# Iteration 44, loss = 1590535488.55861449
# Iteration 45, loss = 1592867938.85577488
# Iteration 46, loss = 1570051039.80150723
# Iteration 47, loss = 1563499462.86045861
# Iteration 48, loss = 1552782185.88819790
# Iteration 49, loss = 1548671777.13331985
# Iteration 50, loss = 1536212394.27200389
# Iteration 51, loss = 1524979987.89099073
# Iteration 52, loss = 1517204968.69012308
# Iteration 53, loss = 1510765024.05322337
# Iteration 54, loss = 1500256956.46474814
# Iteration 55, loss = 1497726477.70558977
# Iteration 56, loss = 1483400257.73565221
# Iteration 910, loss = 126628385.96722037
# Iteration 911, loss = 125860208.97691597
# Iteration 912, loss = 125992471.08137295
# Iteration 913, loss = 126092430.61317411
# Iteration 914, loss = 125311960.80179785
# Iteration 915, loss = 125281360.52162291
# Iteration 916, loss = 125582324.81386058
# Iteration 917, loss = 125504728.86704627
# Iteration 918, loss = 124799695.30089308
# Iteration 919, loss = 125584723.76579732
# Iteration 920, loss = 125564594.01466265
# Iteration 921, loss = 126354810.65131475
# Iteration 922, loss = 124999239.65893339
# Iteration 923, loss = 126622435.21692778
# Iteration 924, loss = 127397796.23379335
# Iteration 925, loss = 124852833.95213495
# Iteration 926, loss = 126308124.44147104
# Iteration 927, loss = 123880776.65798859
# Iteration 928, loss = 124793904.69425626
# Iteration 929, loss = 125699036.10375258
# Iteration 930, loss = 123401394.36212225
# Iteration 931, loss = 124539880.71757825
# Iteration 932, loss = 122669366.38681345
# Iteration 933, loss = 125458363.08773997
# Iteration 934, loss = 123032215.32130845
# Iteration 935, loss = 125294038.00733429
# Iteration 936, loss = 124150677.42375568
# Iteration 937, loss = 122785769.74757095
# Iteration 938, loss = 123336628.47467095
# Iteration 939, loss = 123673680.99535497
# Iteration 940, loss = 122544950.40514615
# Iteration 941, loss = 124597983.29569374
# Iteration 942, loss = 122424602.13552950
# Iteration 943, loss = 122639580.42156556
# Iteration 944, loss = 123843792.38106726
# Iteration 945, loss = 121649089.36647500
# Iteration 946, loss = 121160042.44487518
# Iteration 947, loss = 121729723.43790060
# Iteration 948, loss = 121788751.39852606
# Iteration 949, loss = 122891762.93806003
# Iteration 950, loss = 120235003.80790833
# Iteration 951, loss = 122055161.56842169
# Iteration 952, loss = 120684254.99302036
# Iteration 953, loss = 120401368.80254026
# Iteration 954, loss = 122382103.53949107
# Iteration 955, loss = 121138518.57581419
# Iteration 956, loss = 120812251.02326900
# Iteration 957, loss = 120504823.90370922
# Iteration 958, loss = 120360320.58634688
# Iteration 959, loss = 120975565.32013024
# Iteration 960, loss = 120614098.69026566
# Iteration 961, loss = 122491801.24982101
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# -8.076457032093304

# %%
alg3
# cv_results_3['test_score'].mean()
# MLPRegressor(alpha=0.05, batch_size=15, hidden_layer_sizes=(345, 31, 1),
            #  learning_rate='adaptive', max_iter=1000, verbose=True)
# Out:
# MLPRegressor(alpha=0.05, batch_size=15, hidden_layer_sizes=(345, 31, 1),
#              learning_rate='adaptive', max_iter=1000, verbose=True)

# %%
# alg3.fit()

# %%
from sklearn.neural_network import MLPRegressor
alg4 = MLPRegressor(
    hidden_layer_sizes = (345, 31,1), 
    max_iter=1000,verbose=True, 
    activation = 'relu', 
    solver = 'sgd', 
    alpha = .0005,
    batch_size = 100,
    momentum = .001,
    learning_rate_init = .02,
    learning_rate = 'adaptive')

cv_results_4 = model_selection.cross_validate(
    alg4, mlb_in_train_1, mlb_in_train_tar, 
    cv  = cv_split, 
    scoring='neg_mean_absolute_percentage_error')

# %%
cv_results_4['test_score'].mean()
# Out:
# -1.3104393372699292e+18

# %%
#

# %% [markdown]
# ---

# %%
from sklearn.linear_model import Ridge, LinearRegression, Lasso
from sklearn import model_selection
cv_split = model_selection.ShuffleSplit(
    n_splits = 6, test_size = .15, train_size = .5, random_state = 529)
alg5 = Lasso()

cv_results_5 = model_selection.cross_validate(
    alg5, mlb_in_train_1, mlb_in_train_tar, 
    cv  = cv_split, scoring='neg_mean_absolute_percentage_error')
cv_results_5['test_score'].mean()

# %%
from sklearn.ensemble import RandomForestRegressor
alg6 = RandomForestRegressor(n_estimators = 11, 
        max_depth = 31,
        min_samples_split = 3, 
        min_samples_leaf=2, 
        # max_leaf_nodes = 31
        )
cv_results_6 = model_selection.cross_validate(
    alg6, mlb_in_train_1, mlb_in_train_tar, 
    cv  = cv_split, scoring='neg_mean_absolute_percentage_error')
cv_results_6['test_score'].mean()
# Out:
# -17.731608588325205

# %% [markdown]
# ## test

# %%
test_quant_real = mlb_in_tests_1.pop('quant')
test_quant_real.reset_index(drop = True, inplace = True)

# %%
fit3 = alg3.fit(mlb_in_train_1, mlb_in_train_tar)
# Out:
# Iteration 1, loss = 2194307475.07488298
# Iteration 2, loss = 2194307209.87118387
# Iteration 3, loss = 2194306404.63462210
# Iteration 4, loss = 2183854368.16920567
# Iteration 5, loss = 2150902666.77700090
# Iteration 6, loss = 2101298030.92456055
# Iteration 7, loss = 2032545357.34073639
# Iteration 8, loss = 1915217465.00173259
# Iteration 9, loss = 1815867077.67765784
# Iteration 10, loss = 1711482478.52121854
# Iteration 11, loss = 1637867112.59546423
# Iteration 12, loss = 1584852462.14645147
# Iteration 13, loss = 1557414623.11439657
# Iteration 14, loss = 1548971690.62828970
# Iteration 15, loss = 1528977404.32687187
# Iteration 16, loss = 1521736913.60599375
# Iteration 17, loss = 1509617128.34742188
# Iteration 18, loss = 1494019720.19757652
# Iteration 19, loss = 1500808302.35036755
# Iteration 20, loss = 1481284682.38902020
# Iteration 21, loss = 1461445002.12625766
# Iteration 22, loss = 1451093041.04295349
# Iteration 23, loss = 1441095759.68513680
# Iteration 24, loss = 1434952641.66782236
# Iteration 25, loss = 1424750305.91896343
# Iteration 26, loss = 1409222221.03327060
# Iteration 27, loss = 1402649081.31563282
# Iteration 28, loss = 1398962555.42409801
# Iteration 29, loss = 1380370200.54413819
# Iteration 30, loss = 1373885430.31032181
# Iteration 31, loss = 1372094309.26365232
# Iteration 32, loss = 1351202353.63645148
# Iteration 33, loss = 1340737250.49216223
# Iteration 34, loss = 1335540105.97525978
# Iteration 35, loss = 1324349172.53010058
# Iteration 36, loss = 1325132944.65954375
# Iteration 37, loss = 1303605776.69620419
# Iteration 38, loss = 1296479001.59805918
# Iteration 39, loss = 1299686676.13894439
# Iteration 40, loss = 1277612288.17169762
# Iteration 41, loss = 1268634765.37570453
# Iteration 42, loss = 1258156894.90151000
# Iteration 43, loss = 1248304072.56152701
# Iteration 44, loss = 1239651954.73906851
# Iteration 45, loss = 1236867905.65979004
# Iteration 46, loss = 1219521642.09517217
# Iteration 47, loss = 1221634875.35781932
# 4       7432.0
# 5      80613.0
# 6      10810.0
# 7      16623.0
# 8      58582.0
# 9      13519.0
# 10     17608.0
# 11      4949.0
# 12     25481.0
# 13     36348.0
# 14     54433.0
# 15     22149.0
# Name: 1, dtype: float64

# %%
from sklearn import metrics
metrics.mean_absolute_percentage_error(fit3_pre.iloc[:16,1],fit3_pre.iloc[:16,0])
# Out:
# 0.747412532781606

# %%
fit6 = alg6.fit(mlb_in_train_1, mlb_in_train_tar)

# %%
fit6_pre = pd.concat(
    [pd.DataFrame(fit6.predict(mlb_in_tests_1)), test_quant_real],
    axis=1,ignore_index = True
);

fit6_pre
# Out:
#                0         1
# 0    6749.954113    7295.0
# 1    9751.604545   11790.0
# 2   16504.612121   27832.0
# 3   29236.919697  172755.0
# 4   21292.241185    7432.0
# 5   22772.188095   80613.0
# 6   26195.334848   10810.0
# 7   24815.368457   16623.0
# 8   26314.563853   58582.0
# 9   33401.931818   13519.0
# 10  15467.404545   17608.0
# 11  22141.701791    4949.0
# 12  57825.886364   25481.0
# 13  13469.116234   36348.0
# 14  23214.495238   54433.0
# 15  26604.206061   22149.0
# 16  22634.159091   18994.0
# 17  21743.677273     489.0

# %%
from sklearn import metrics
metrics.mean_absolute_percentage_error(fit6_pre[1],fit6_pre[0])
# Out:
# 3.2184286168162735

# %%
import time #implementing in this function the time spent on training the model
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, KFold

def modelfit(alg, dtrain, target, only_predict = False):
    #Fit the algorithm on the data
    time_start = time.perf_counter() #start counting the time
    if not only_predict:
        alg.fit(dtrain, target)
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain)
    
    kfolds = KFold(n_splits=6, shuffle=True, random_state=42)
    
    cv_score = cross_val_score(alg, dtrain,target, cv=kfolds, scoring='neg_mean_squared_error')
    cv_score = np.sqrt(-cv_score)
    
    time_end = time.perf_counter()
    
    total_time = time_end-time_start
    #Print model report:
    print("\nModel Report")
    print("RMSE :  {:.4f}".format(np.sqrt(mean_squared_error(target, dtrain_predictions))))
    print("CV Score : Mean -  %.4f | Std -  %.4f | Min -  %.4f | Max - %.4f" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
    print("Amount of time spent during training the model and cross validation: %4.3f seconds" % (total_time))
    
def plot_feature_importance(model, df):
    feature_importance = model.feature_importances_[:30]
    # make importances relative to max importance
    plt.figure(figsize=(20, 20)) #figure size
    feature_importance = 100.0 * (feature_importance / feature_importance.max()) #making it a percentage relative to the max value
    sorted_idx = np.argsort(feature_importance)
    pos = np.arange(sorted_idx.shape[0]) + .5
    plt.barh(pos, feature_importance[sorted_idx], align='center')
    plt.yticks(pos, df.columns[sorted_idx], fontsize=15) #used train_drop here to show the name of each feature instead of our train_prepared 
    plt.xlabel('Relative Importance', fontsize=20)
    plt.ylabel('Features', fontsize=20)
    plt.title('Variable Importance', fontsize=30)

# %%
lin_reg = LinearRegression()
modelfit(lin_reg, mlb_in_train_1, mlb_in_train_tar)
# Out:
# Model Report
# RMSE :  31750.6865
# CV Score : Mean -  61919.0978 | Std -  22175.4367 | Min -  40175.2052 | Max - 105839.9921
# Amount of time spent during training the model and cross validation: 0.246 seconds

# %%
forest_reg = RandomForestRegressor(n_estimators=3000, 
                                   random_state=529, 
                                   min_samples_leaf=5,
                                   min_samples_split = 5,
                                   max_depth = 25,
                                   n_jobs=-1, oob_score=True)
modelfit(forest_reg, mlb_in_train_1, mlb_in_train_tar)
# Out:
# Model Report
# RMSE :  43667.1852
# CV Score : Mean -  46620.5247 | Std -  27659.3376 | Min -  18933.1537 | Max - 102307.9280
# Amount of time spent during training the model and cross validation: 85.311 seconds

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=421, max_depth = 15, min_samples_split = 5)
modelfit(tree_reg, mlb_in_train_1, mlb_in_train_tar)
# Out:
# Model Report
# RMSE :  19780.1639
# CV Score : Mean -  88137.3955 | Std -  42987.0781 | Min -  26775.9041 | Max - 162303.5689
# Amount of time spent during training the model and cross validation: 0.159 seconds

# %%
 
from sklearn.ensemble import AdaBoostRegressor

# tree_ada = DecisionTreeRegressor(random_state = 42,max_depth = 4)

ada_reg = AdaBoostRegressor(
    tree_reg, n_estimators=300, random_state=42,learning_rate=0.009, loss='square')
modelfit(ada_reg, mlb_in_train_1, mlb_in_train_tar)

# 181.589
# Out:
# Model Report
# RMSE :  1643.2120
# CV Score : Mean -  41260.3441 | Std -  21268.5175 | Min -  16776.4402 | Max - 68221.0368
# Amount of time spent during training the model and cross validation: 10.713 seconds

# %%
forest_reg_pre = pd.concat(
    [pd.DataFrame(forest_reg.predict(mlb_in_tests_1)), test_quant_real], 
    axis = 1,
    join = 'outer',
    ignore_index = True);
forest_reg_pre
# Out:
#                0         1
# 0    8384.514687    7295.0
# 1   11471.869326   11790.0
# 2   16526.981927   27832.0
# 3   23098.157550  172755.0
# 4   17963.921048    7432.0
# 5   26623.122254   80613.0
# 6   26998.857863   10810.0
# 7   23036.273727   16623.0
# 8   27304.401138   58582.0
# 9   35222.814740   13519.0
# 10  11414.710328   17608.0
# 11  22065.711430    4949.0
# 12  74966.328211   25481.0
# 13  12736.731117   36348.0
# 14  28608.992052   54433.0
# 15  22796.048381   22149.0
# 16  21224.391864   18994.0
# 17  24344.990220     489.0

# %%
metrics.mean_absolute_percentage_error(forest_reg_pre[1],forest_reg_pre[0])
# Out:
# 3.5203720550254523

# %%
ada_reg_pre = pd.concat(
    [pd.DataFrame(ada_reg.predict(mlb_in_tests_1)), test_quant_real], 
    axis = 1,
    join = 'outer',
    ignore_index = True);
ada_reg_pre
# Out:
#            0         1
# 0    1495.75    7295.0
# 1   12704.25   11790.0
# 2   13367.00   27832.0
# 3   24983.00  172755.0
# 4   24126.00    7432.0
# 5   20542.25   80613.0
# 6   21303.00   10810.0
# 7   28242.00   16623.0
# 8   24965.00   58582.0
# 9   20873.00   13519.0
# 10   1159.00   17608.0
# 11  23982.00    4949.0
# 12  42757.00   25481.0
# 13  13564.00   36348.0
# 14  29084.00   54433.0
# 15  27927.00   22149.0
# 16  28553.75   18994.0
# 17  26322.50     489.0

# %%
metrics.mean_absolute_percentage_error(ada_reg_pre[1],ada_reg_pre[0])
# Out:
# 3.7872460788382796

# %%
metrics.mean_absolute_error(ada_reg_pre[1],ada_reg_pre[0])
# Out:
# 25047.805555555555

# %%
sum(abs((ada_reg_pre[1]-ada_reg_pre[0])/ada_reg_pre[1]))/18
# Out:
# 3.7872460788382796

# %% [markdown]
# lgbm

# %%
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.metrics import mean_absolute_percentage_error

# %%
def objective(trial, X=mlb_in_train_1, y=mlb_in_train_tar):

    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=meta_random_seed)


    lgb_params={
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-2),
        'max_depth': trial.suggest_int('max_depth', 6, 31),
        'num_leaves': trial.suggest_int('num_leaves', 31, 120),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-1, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-1, 1),
        'random_state': meta_random_seed,
        'metric': 'mse',
        'n_estimators': trial.suggest_int('n_estimators', 6, 3000),
        'n_jobs': -1,
        'cat_feature': [x for x in range(len(categorical_columns))],
        'bagging_seed': 2021,
        'feature_fraction_seed': 2021,
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 0.9),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 500),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.7, 0.9),
        'max_bin': trial.suggest_int('max_bin', 128, 1024),
        'min_data_per_group': trial.suggest_int('min_data_per_group', 5, 50),
        'cat_smooth': trial.suggest_int('cat_smooth', 10, 250),
        'cat_l2': trial.suggest_int('cat_l2', 1, 20)
    }

    lgb = LGBMRegressor(
        **lgb_params
    )
    lgb.fit(
        X_train,
        y_train,
        eval_set=(X_test,y_test),
        eval_metric='mean_absolute_percentage_error',
        early_stopping_rounds=100,
        verbose=False
    )
    predictions=lgb.predict(X_test)

    return mean_absolute_percentage_error(y_test, predictions)

# %%
meta_random_seed = 529
categorical_columns=['']
study = optuna.create_study(direction='minimize')
study.optimize(objective, timeout=3600*7, n_trials=25)
# Out:
# [I 2021-06-24 16:18:06,329] A new study created in memory with name: no-name-35c5762b-c4ea-45db-b74b-c4fd74ea4b8c
# [I 2021-06-24 16:18:06,411] Trial 0 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.007674915293680241, 'max_depth': 7, 'num_leaves': 114, 'reg_alpha': 0.9067163907386172, 'reg_lambda': 0.32198158510100305, 'n_estimators': 998, 'colsample_bytree': 0.7311765774956949, 'min_child_samples': 399, 'subsample_freq': 10, 'subsample': 0.706755721969521, 'max_bin': 345, 'min_data_per_group': 44, 'cat_smooth': 136, 'cat_l2': 19}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,464] Trial 1 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0012696940324347491, 'max_depth': 25, 'num_leaves': 104, 'reg_alpha': 0.5235199216434151, 'reg_lambda': 0.7062441793935992, 'n_estimators': 2772, 'colsample_bytree': 0.7990863423157377, 'min_child_samples': 80, 'subsample_freq': 1, 'subsample': 0.7386705421249349, 'max_bin': 523, 'min_data_per_group': 11, 'cat_smooth': 140, 'cat_l2': 4}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,549] Trial 2 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0006926727774285793, 'max_depth': 17, 'num_leaves': 45, 'reg_alpha': 0.8107095057880677, 'reg_lambda': 0.5207095653588614, 'n_estimators': 2351, 'colsample_bytree': 0.877783239662585, 'min_child_samples': 434, 'subsample_freq': 3, 'subsample': 0.7353982808494925, 'max_bin': 416, 'min_data_per_group': 18, 'cat_smooth': 112, 'cat_l2': 20}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,614] Trial 3 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.002331067398870439, 'max_depth': 20, 'num_leaves': 46, 'reg_alpha': 0.6562244242620838, 'reg_lambda': 0.6958354915787641, 'n_estimators': 2885, 'colsample_bytree': 0.7070887547385647, 'min_child_samples': 474, 'subsample_freq': 4, 'subsample': 0.7885916501656605, 'max_bin': 768, 'min_data_per_group': 6, 'cat_smooth': 246, 'cat_l2': 10}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,794] Trial 4 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0065720081255330656, 'max_depth': 28, 'num_leaves': 79, 'reg_alpha': 0.3134218188933078, 'reg_lambda': 0.5938271630954169, 'n_estimators': 740, 'colsample_bytree': 0.7172784761314923, 'min_child_samples': 437, 'subsample_freq': 10, 'subsample': 0.8860431634561533, 'max_bin': 851, 'min_data_per_group': 5, 'cat_smooth': 228, 'cat_l2': 3}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,853] Trial 5 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.008312741082736006, 'max_depth': 27, 'num_leaves': 41, 'reg_alpha': 0.44781710069891023, 'reg_lambda': 0.1299649078000644, 'n_estimators': 1066, 'colsample_bytree': 0.7159209956224234, 'min_child_samples': 220, 'subsample_freq': 10, 'subsample': 0.746949078483824, 'max_bin': 334, 'min_data_per_group': 34, 'cat_smooth': 41, 'cat_l2': 5}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,927] Trial 6 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.006404332134206766, 'max_depth': 27, 'num_leaves': 79, 'reg_alpha': 0.31082535037505893, 'reg_lambda': 0.636936070509779, 'n_estimators': 2236, 'colsample_bytree': 0.8041706464274019, 'min_child_samples': 95, 'subsample_freq': 6, 'subsample': 0.8300451528851299, 'max_bin': 791, 'min_data_per_group': 14, 'cat_smooth': 64, 'cat_l2': 20}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:06,995] Trial 7 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.001518239273387568, 'max_depth': 29, 'num_leaves': 118, 'reg_alpha': 0.8043543195871564, 'reg_lambda': 0.11831446803336125, 'n_estimators': 1317, 'colsample_bytree': 0.8380605588598891, 'min_child_samples': 390, 'subsample_freq': 9, 'subsample': 0.7057311082342381, 'max_bin': 531, 'min_data_per_group': 47, 'cat_smooth': 80, 'cat_l2': 1}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:07,051] Trial 8 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0007895563830214415, 'max_depth': 16, 'num_leaves': 41, 'reg_alpha': 0.8251287857115792, 'reg_lambda': 0.20985326453187997, 'n_estimators': 913, 'colsample_bytree': 0.7704738317081283, 'min_child_samples': 108, 'subsample_freq': 4, 'subsample': 0.8381238214027554, 'max_bin': 648, 'min_data_per_group': 50, 'cat_smooth': 141, 'cat_l2': 13}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:07,117] Trial 9 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0067550974009339855, 'max_depth': 9, 'num_leaves': 78, 'reg_alpha': 0.40580823868305405, 'reg_lambda': 0.4699107171486657, 'n_estimators': 681, 'colsample_bytree': 0.773942057486304, 'min_child_samples': 219, 'subsample_freq': 10, 'subsample': 0.7742067432208025, 'max_bin': 140, 'min_data_per_group': 30, 'cat_smooth': 34, 'cat_l2': 8}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:07,304] Trial 10 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.009926144552233309, 'max_depth': 7, 'num_leaves': 102, 'reg_alpha': 0.1385263030501993, 'reg_lambda': 0.9625006949979895, 'n_estimators': 6, 'colsample_bytree': 0.7474413026188829, 'min_child_samples': 333, 'subsample_freq': 7, 'subsample': 0.7077317958108884, 'max_bin': 206, 'min_data_per_group': 41, 'cat_smooth': 197, 'cat_l2': 16}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:07,481] Trial 11 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0038736710285222084, 'max_depth': 21, 'num_leaves': 119, 'reg_alpha': 0.6026097116391955, 'reg_lambda': 0.3460284227669808, 'n_estimators': 1831, 'colsample_bytree': 0.8230264380257636, 'min_child_samples': 59, 'subsample_freq': 1, 'subsample': 0.7033107089314042, 'max_bin': 402, 'min_data_per_group': 21, 'cat_smooth': 166, 'cat_l2': 15}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:07,649] Trial 12 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.009732044211932689, 'max_depth': 12, 'num_leaves': 100, 'reg_alpha': 0.6705792181734911, 'reg_lambda': 0.8416719692637525, 'n_estimators': 2944, 'colsample_bytree': 0.8677083918624645, 'min_child_samples': 299, 'subsample_freq': 1, 'subsample': 0.7488036565971632, 'max_bin': 1016, 'min_data_per_group': 40, 'cat_smooth': 118, 'cat_l2': 7}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:07,832] Trial 13 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.004225994596246181, 'max_depth': 23, 'num_leaves': 102, 'reg_alpha': 0.9907795105376175, 'reg_lambda': 0.3259600684636581, 'n_estimators': 176, 'colsample_bytree': 0.7514111188650371, 'min_child_samples': 155, 'subsample_freq': 8, 'subsample': 0.7271359029445277, 'max_bin': 544, 'min_data_per_group': 10, 'cat_smooth': 172, 'cat_l2': 1}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:08,000] Trial 14 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.007972665638924983, 'max_depth': 24, 'num_leaves': 111, 'reg_alpha': 0.9319701052643202, 'reg_lambda': 0.7987595727737209, 'n_estimators': 1656, 'colsample_bytree': 0.7902391378301651, 'min_child_samples': 339, 'subsample_freq': 2, 'subsample': 0.7679649837695786, 'max_bin': 216, 'min_data_per_group': 24, 'cat_smooth': 145, 'cat_l2': 12}. Best is trial 0 with value: 77.68637069145414.
# [I 2021-06-24 16:18:08,411] Trial 15 finished with value: 53.264403486377525 and parameters: {'learning_rate': 0.002920138255806272, 'max_depth': 13, 'num_leaves': 63, 'reg_alpha': 0.503043607150654, 'reg_lambda': 0.4690767318855418, 'n_estimators': 379, 'colsample_bytree': 0.8425753983202822, 'min_child_samples': 11, 'subsample_freq': 5, 'subsample': 0.820096862724736, 'max_bin': 310, 'min_data_per_group': 34, 'cat_smooth': 93, 'cat_l2': 16}. Best is trial 15 with value: 53.264403486377525.
# [I 2021-06-24 16:18:08,817] Trial 16 finished with value: 47.76610439576945 and parameters: {'learning_rate': 0.0032718578889943035, 'max_depth': 12, 'num_leaves': 60, 'reg_alpha': 0.17408138570157833, 'reg_lambda': 0.398764373728789, 'n_estimators': 396, 'colsample_bytree': 0.8964110845603139, 'min_child_samples': 10, 'subsample_freq': 5, 'subsample': 0.8134302500644891, 'max_bin': 301, 'min_data_per_group': 38, 'cat_smooth': 96, 'cat_l2': 18}. Best is trial 16 with value: 47.76610439576945.
# [I 2021-06-24 16:18:09,542] Trial 17 finished with value: 63.082324740505975 and parameters: {'learning_rate': 0.002999600151117052, 'max_depth': 13, 'num_leaves': 58, 'reg_alpha': 0.11886209666992437, 'reg_lambda': 0.43578765619028176, 'n_estimators': 369, 'colsample_bytree': 0.8545113976293003, 'min_child_samples': 1, 'subsample_freq': 5, 'subsample': 0.8278290850044538, 'max_bin': 256, 'min_data_per_group': 34, 'cat_smooth': 87, 'cat_l2': 17}. Best is trial 16 with value: 47.76610439576945.
# [I 2021-06-24 16:18:09,727] Trial 18 finished with value: 59.394562990593265 and parameters: {'learning_rate': 0.005019407306645386, 'max_depth': 13, 'num_leaves': 63, 'reg_alpha': 0.1909204013572914, 'reg_lambda': 0.41402447349702226, 'n_estimators': 417, 'colsample_bytree': 0.8975414889347494, 'min_child_samples': 26, 'subsample_freq': 6, 'subsample': 0.8649342729446965, 'max_bin': 156, 'min_data_per_group': 36, 'cat_smooth': 103, 'cat_l2': 18}. Best is trial 16 with value: 47.76610439576945.
# [I 2021-06-24 16:18:09,872] Trial 19 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0030197919396682134, 'max_depth': 11, 'num_leaves': 65, 'reg_alpha': 0.2520774288878732, 'reg_lambda': 0.2681595601400529, 'n_estimators': 448, 'colsample_bytree': 0.8893259024013511, 'min_child_samples': 145, 'subsample_freq': 5, 'subsample': 0.8007595426539585, 'max_bin': 291, 'min_data_per_group': 28, 'cat_smooth': 58, 'cat_l2': 14}. Best is trial 16 with value: 47.76610439576945.
# [I 2021-06-24 16:18:10,027] Trial 20 finished with value: 73.80522400809302 and parameters: {'learning_rate': 0.005125938320086006, 'max_depth': 15, 'num_leaves': 32, 'reg_alpha': 0.4172618200933631, 'reg_lambda': 0.5097275923257714, 'n_estimators': 13, 'colsample_bytree': 0.8484465304206156, 'min_child_samples': 8, 'subsample_freq': 7, 'subsample': 0.8100221215761686, 'max_bin': 429, 'min_data_per_group': 38, 'cat_smooth': 23, 'cat_l2': 17}. Best is trial 16 with value: 47.76610439576945.
# [I 2021-06-24 16:18:10,224] Trial 21 finished with value: 54.57945369347921 and parameters: {'learning_rate': 0.005217092577868415, 'max_depth': 14, 'num_leaves': 64, 'reg_alpha': 0.20242004062298477, 'reg_lambda': 0.4207537209202757, 'n_estimators': 418, 'colsample_bytree': 0.8971426315012005, 'min_child_samples': 29, 'subsample_freq': 6, 'subsample': 0.8716562433610315, 'max_bin': 135, 'min_data_per_group': 36, 'cat_smooth': 92, 'cat_l2': 18}. Best is trial 16 with value: 47.76610439576945.
# [I 2021-06-24 16:18:10,428] Trial 22 finished with value: 39.981035302704484 and parameters: {'learning_rate': 0.005136975656960963, 'max_depth': 9, 'num_leaves': 55, 'reg_alpha': 0.20817676381652056, 'reg_lambda': 0.3934488653297847, 'n_estimators': 255, 'colsample_bytree': 0.898763145328619, 'min_child_samples': 32, 'subsample_freq': 4, 'subsample': 0.8626632385864561, 'max_bin': 170, 'min_data_per_group': 32, 'cat_smooth': 77, 'cat_l2': 20}. Best is trial 22 with value: 39.981035302704484.
# [I 2021-06-24 16:18:10,564] Trial 23 finished with value: 74.30206018143667 and parameters: {'learning_rate': 0.0037201966233298173, 'max_depth': 9, 'num_leaves': 56, 'reg_alpha': 0.3241357319704986, 'reg_lambda': 0.2169283265993429, 'n_estimators': 23, 'colsample_bytree': 0.8731232324054011, 'min_child_samples': 51, 'subsample_freq': 4, 'subsample': 0.8537056604672968, 'max_bin': 283, 'min_data_per_group': 31, 'cat_smooth': 10, 'cat_l2': 20}. Best is trial 22 with value: 39.981035302704484.
# [I 2021-06-24 16:18:10,724] Trial 24 finished with value: 77.68637069145414 and parameters: {'learning_rate': 0.0020757487682473196, 'max_depth': 10, 'num_leaves': 72, 'reg_alpha': 0.10208718815699808, 'reg_lambda': 0.38303670828329345, 'n_estimators': 665, 'colsample_bytree': 0.8197960434405596, 'min_child_samples': 144, 'subsample_freq': 3, 'subsample': 0.8999747729668832, 'max_bin': 128, 'min_data_per_group': 44, 'cat_smooth': 67, 'cat_l2': 16}. Best is trial 22 with value: 39.981035302704484.

# %%
study.best_params
# Out:
# {'learning_rate': 0.005136975656960963,
#  'max_depth': 9,
#  'num_leaves': 55,
#  'reg_alpha': 0.20817676381652056,
#  'reg_lambda': 0.3934488653297847,
#  'n_estimators': 255,
#  'colsample_bytree': 0.898763145328619,
#  'min_child_samples': 32,
#  'subsample_freq': 4,
#  'subsample': 0.8626632385864561,
#  'max_bin': 170,
#  'min_data_per_group': 32,
#  'cat_smooth': 77,
#  'cat_l2': 20}

# %%
mlb_in_train_tar = pd.DataFrame(mlb_in_train_tar)

# %%
from sklearn.model_selection import StratifiedKFold,RepeatedKFold
from scipy.special import expit
from sklearn.calibration import CalibratedClassifierCV

random_state = 1026529
n_folds = 6
k_fold = RepeatedKFold(n_splits=n_folds, random_state=random_state)

# y = train_df["target"]

# xgb_train_preds = np.zeros(len(train_df.index), )
# xgb_test_preds = np.zeros(len(test_df.index), )
# xgb_features = xgb_cat_features + list(numerical_columns)

lgbm_train_preds = np.zeros(len(mlb_in_train_1.index), )
lgbm_test_preds = np.zeros(len(mlb_in_train_tar.index), )
# lgbm_features = lgb_cat_features + list(numerical_columns)

# cb_train_preds = np.zeros(len(train_df.index), )
# cb_test_preds = np.zeros(len(test_df.index), )
# cb_features = cb_cat_features + list(numerical_columns)

# ridge_train_preds = np.zeros(len(train_df.index), )
# ridge_test_preds = np.zeros(len(test_df.index), )
# ridge_features = ridge_cat_features + list(numerical_columns)

# %%
train_df = mlb_in_train_1
y = mlb_in_train_tar
test_df = mlb_in_tests_1

# %%
for fold, (train_index, test_index) in enumerate(
    k_fold.split(train_df, y)):
    print("--> Fold {}".format(fold + 1))
    y_train = y.iloc[train_index]
    y_valid = y.iloc[test_index]

    lgbm_x_train = pd.DataFrame(train_df.iloc[train_index])
    lgbm_x_valid = pd.DataFrame(train_df.iloc[test_index])

    
    ########## LGBM model ##########
    lgbm_model = LGBMRegressor(
        random_state=random_state,
        learning_rate=0.005136975656960963,
        max_depth=9,
        num_leaves= 55,
        reg_alpha=0.20817676381652056,
        reg_lambda= 0.3934488653297847,
        n_estimators= 255,
        colsample_bytree= 0.898763145328619,
        min_child_samples= 32,
        subsample_freq = 4,
        subsample = 0.8626632385864561,
        max_bin= 170,
        min_data_per_group=32,
        cat_smooth=77,
        cat_l2= 20,
        verbose=-1,
    )
    lgbm_model.fit(
        train_df,
        y,
        eval_set=[(lgbm_x_valid, y_valid)], 
        verbose=0,
    )

    train_oof_preds = lgbm_model.predict(lgbm_x_valid)
    # test_oof_preds = lgbm_model.predict(test_df)
    lgbm_train_preds[test_index] = train_oof_preds
    # lgbm_test_preds += test_oof_preds / n_folds
    
    print(": LGB - RMSE = {}".format(mean_absolute_percentage_error(y_valid, train_oof_preds)))
# Out:
# --> Fold 1
# : LGB - RMSE = 22.017476340807537
# --> Fold 2
# : LGB - RMSE = 73.33609996810625
# --> Fold 3
# : LGB - RMSE = 36.44202949811168
# --> Fold 4
# : LGB - RMSE = 205.78513993635454
# --> Fold 5
# : LGB - RMSE = 29.852019454832853
# --> Fold 6
# : LGB - RMSE = 27.09309628828924
# --> Fold 7
# : LGB - RMSE = 44.85831169299779
# --> Fold 8
# : LGB - RMSE = 42.697217663715165
# --> Fold 9
# : LGB - RMSE = 15.956568147038784
# --> Fold 10
# : LGB - RMSE = 14.181854661347812
# --> Fold 11
# : LGB - RMSE = 61.88464801418783
# --> Fold 12
# : LGB - RMSE = 214.94726130721472
# --> Fold 13
# : LGB - RMSE = 214.89305429940734
# --> Fold 14
# : LGB - RMSE = 54.965125386439865
# --> Fold 15
# : LGB - RMSE = 26.11421677649058
# --> Fold 16
# : LGB - RMSE = 24.895203114889668
# --> Fold 17
# : LGB - RMSE = 54.478542537794034
# --> Fold 18
# : LGB - RMSE = 19.179719371480573
# --> Fold 19
# : LGB - RMSE = 223.8723041230306
# --> Fold 20
# : LGB - RMSE = 58.14628863296273
# --> Fold 21
# : LGB - RMSE = 21.036006972262275
# --> Fold 22
# : LGB - RMSE = 33.54067699442892
# --> Fold 23
# : LGB - RMSE = 36.9009606082031
# --> Fold 24
# : LGB - RMSE = 21.02962415561446
# --> Fold 25
# : LGB - RMSE = 13.468539170130013
# --> Fold 26
# : LGB - RMSE = 46.64650188509001
# --> Fold 27
# : LGB - RMSE = 37.99478866595966
# --> Fold 28
# : LGB - RMSE = 22.70904471807418
# --> Fold 29
# : LGB - RMSE = 22.94659545873079
# --> Fold 30
# : LGB - RMSE = 250.76039158851745
# --> Fold 31
# : LGB - RMSE = 61.95297031323431
# --> Fold 32
# : LGB - RMSE = 29.03182273396161
# --> Fold 33
# : LGB - RMSE = 5.095031002883265
# --> Fold 34
# : LGB - RMSE = 61.58062870531614
# --> Fold 35
# : LGB - RMSE = 21.09045561928869
# --> Fold 36
# : LGB - RMSE = 215.77495311181806
# --> Fold 37
# : LGB - RMSE = 215.94089129423014
# --> Fold 38
# : LGB - RMSE = 52.32900237757618
# --> Fold 39
# : LGB - RMSE = 52.52911572403272
# --> Fold 40
# : LGB - RMSE = 52.67909565573714
# --> Fold 41
# : LGB - RMSE = 14.897310565867398
# --> Fold 42
# : LGB - RMSE = 6.150445869058534
# --> Fold 43
# : LGB - RMSE = 29.663690816402905
# --> Fold 44
# : LGB - RMSE = 16.490521684208808
# --> Fold 45
# : LGB - RMSE = 38.04002596211725
# --> Fold 46
# : LGB - RMSE = 46.127615311340676
# --> Fold 47
# : LGB - RMSE = 58.911663513649565
# --> Fold 48
# : LGB - RMSE = 205.29234419878293
# --> Fold 49
# : LGB - RMSE = 33.168970655170334
# --> Fold 50
# : LGB - RMSE = 24.02042489976337
# --> Fold 51
# : LGB - RMSE = 45.14182275391167
# --> Fold 52
# : LGB - RMSE = 35.07977595811667
# --> Fold 53
# : LGB - RMSE = 220.04603532390064
# --> Fold 54
# : LGB - RMSE = 37.06883189563936
# --> Fold 55
# : LGB - RMSE = 236.0193816488999
# --> Fold 56
# : LGB - RMSE = 26.4030350550692
# --> Fold 57
# : LGB - RMSE = 22.96802343945144
# --> Fold 58
# : LGB - RMSE = 2.9526968013209274
# --> Fold 59
# : LGB - RMSE = 49.76764149742089
# --> Fold 60
# : LGB - RMSE = 56.415083044339696

# %%
test_oof_preds = lgbm_model.predict(test_df)

# %%
mean_absolute_percentage_error(test_quant_real,test_oof_preds)
# Out:
# 4.22757382912277

# %% [markdown]
# ---

# %% [markdown]
# # MLB IN only time series

# %%
mlb_in_train_times = mlb_in_train_1[['year', 'month', 'date']]
mlb_in_tests_times = mlb_in_tests_1[['year', 'month', 'date']]

# %%
lin_reg = LinearRegression()
modelfit(lin_reg, mlb_in_train_times, mlb_in_train_tar)
# Out:
# Model Report
# RMSE :  58874.4550
# CV Score : Mean -  49767.1451 | Std -  33095.8576 | Min -  22088.0818 | Max - 116729.1548
# Amount of time spent during training the model and cross validation: 0.113 seconds

# %%
forest_reg = RandomForestRegressor(n_estimators=3000, 
                                   random_state=529, 
                                   min_samples_leaf=5,
                                   min_samples_split = 5,
                                   max_depth = 25,
                                   n_jobs=-1, oob_score=True)
modelfit(forest_reg, mlb_in_train_times, mlb_in_train_tar)
# Out:
# Model Report
# RMSE :  52608.8477
# CV Score : Mean -  50757.9233 | Std -  31504.5419 | Min -  24113.8041 | Max - 115324.7016
# Amount of time spent during training the model and cross validation: 76.703 seconds

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

tree_reg = DecisionTreeRegressor(
    random_state=421, max_depth = 15, min_samples_split = 5)
modelfit(tree_reg, mlb_in_train_1, mlb_in_train_tar) 

# tree_ada = DecisionTreeRegressor(random_state = 42,max_depth = 4)

ada_reg = AdaBoostRegressor(
    tree_reg, n_estimators=300, random_state=42,learning_rate=0.009, loss='square')
modelfit(ada_reg, mlb_in_train_times, mlb_in_train_tar)

# 181.589
# Out:
# Model Report
# RMSE :  19780.1639
# CV Score : Mean -  88137.3955 | Std -  42987.0781 | Min -  26775.9041 | Max - 162303.5689
# Amount of time spent during training the model and cross validation: 0.138 seconds
#
# Model Report
# RMSE :  9552.1449
# CV Score : Mean -  50228.3440 | Std -  33095.4794 | Min -  20021.6018 | Max - 113961.1782
# Amount of time spent during training the model and cross validation: 7.497 seconds

# %%
forest_reg_pre2 = pd.concat(
    [pd.DataFrame(forest_reg.predict(mlb_in_tests_times)), test_quant_real], 
    axis = 1,
    join = 'outer',
    ignore_index = True);
forest_reg_pre2
# Out:
#                0         1
# 0    9824.572655    7295.0
# 1    9933.735421   11790.0
# 2   11359.208885   27832.0
# 3   26523.414284  172755.0
# 4   30245.766592    7432.0
# 5   13893.093600   80613.0
# 6   25438.005251   10810.0
# 7   28192.603881   16623.0
# 8   28148.431259   58582.0
# 9   26132.864725   13519.0
# 10  27272.572725   17608.0
# 11  24769.967384    4949.0
# 12  10975.330944   25481.0
# 13   9460.161757   36348.0
# 14   9627.001381   54433.0
# 15  10395.665662   22149.0
# 16  16375.253509   18994.0
# 17  19839.318553     489.0

# %%
metrics.mean_absolute_percentage_error(forest_reg_pre2[1],forest_reg_pre2[0])
# Out:
# 3.1259660819336483

# %%
ada_reg_pre2 = pd.concat(
    [pd.DataFrame(ada_reg.predict(mlb_in_tests_times)), test_quant_real], 
    axis = 1,
    join = 'outer',
    ignore_index = True);
ada_reg_pre2
# Out:
#                0         1
# 0   13132.000000    7295.0
# 1   20429.333333   11790.0
# 2     345.500000   27832.0
# 3      56.250000  172755.0
# 4      48.666667    7432.0
# 5    1922.000000   80613.0
# 6   35381.500000   10810.0
# 7   42543.000000   16623.0
# 8   25601.666667   58582.0
# 9   11824.000000   13519.0
# 10  13800.000000   17608.0
# 11  29223.000000    4949.0
# 12   2611.333333   25481.0
# 13   3794.250000   36348.0
# 14   8998.000000   54433.0
# 15  10609.000000   22149.0
# 16  12626.666667   18994.0
# 17  29631.000000     489.0

# %%
metrics.mean_absolute_percentage_error(ada_reg_pre2[1],ada_reg_pre2[0])
# Out:
# 4.345039470809149

# %% [markdown]
# ---

# %% [markdown]
# # outbOund MLB

# %%
mlb_out = pd.read_csv('./mlb_ou.csv')
mlb_out.dropna(subset=['SKU', '品名'], inplace=True)
(mlb_out).shape

# %%
mlb_out.columns = ['date','code','sku','name','quant','loc','province','city']

# %%
mlb_out
# Out:
#                    date     code                sku  \
# 0        2021/2/4 15:11  74716.0    71HDM104150L120
# 1        2021/2/4 15:11  74717.0    71SKM104150L120
# 2        2021/2/4 15:02  75190.0    71MTF206143D155
# 3        2021/2/4 15:08  75209.0    71TS2504150L120
# 4        2021/2/4 16:53  75246.0    72SHC101150I220
# ...                 ...      ...                ...
# 467622  2021/6/19 23:28      NaN  3ASXXA11N07INS260
# 467623  2021/6/19 23:28      NaN  3ASXXA11N07INS265
# 467624  2021/6/19 23:28      NaN  3ASXXA11N07INS270
# 467625  2021/6/19 23:28      NaN  3ASXXA11N07INS275
# 467626  2021/6/19 23:28      NaN  3ASXXA11N07INS280
#
#                                               name  quant        loc province  \
# 0          8809727312654DAIMAROO 共用 COMFORTABLE 帽衫      1  A01-B-118      四川省
# 1              8809727314573DAIMAROO 女士 REGULAR 裙子      1  A02-C-115      四川省
# 2          8809727319110DAIMAROO 共用 COMFORTABLE 卫衣      1  A01-C-102      浙江省
# 3       8809727315730DAIMAROO 共用 COMFORTABLE 短袖领T恤      1  A02-C-019      广东省
# 4                               8809703531659饰品 共用      1  A07-D-016      四川省
# ...                                            ...    ...        ...      ...
# 467622                     8809792297979BASIC  运动鞋     10      MT-03      江苏省
# 467623                     8809792279517BASIC  运动鞋     10      MT-03      江苏省
# 467624                     8809792297986BASIC  运动鞋     10      MT-03      江苏省
# 467625                     8809792279524BASIC  运动鞋     10      MT-03      江苏省
# 467626                     8809792297993BASIC  运动鞋     10      MT-03      江苏省
#
#        city
# 0       成都市
# 1       成都市
# 2       杭州市
# 3       广州市
# 4       成都市
# ...     ...
# 467622  无锡市
# 467623  无锡市
# 467624  无锡市
# 467625  无锡市
# 467626  无锡市
#
# [467485 rows x 8 columns]

# %%
def data_ppp(mlb_in):
    mlb_in['top'] = mlb_in['name'].str.extract(r'(衣|夹克|衫|服|马甲|恤)').isnull() != True
    mlb_in['top'] = mlb_in['top'].astype(int)
    mlb_in['sp'] = mlb_in['name'].str.extract(r'(饰品|配饰)').isnull() != True
    mlb_in['sp'] = mlb_in['sp'].astype(int)
    mlb_in['cap'] = mlb_in['name'].str.extract(r'(.+CAP|帽)').isnull() != True
    mlb_in['cap'] = mlb_in['cap'].astype(int)
    mlb_in['pack'] = mlb_in['name'].str.extract(r'(.+PACK|包)').isnull() != True
    mlb_in['pack'] = mlb_in['pack'].astype(int)
    mlb_in['female'] = mlb_in['name'].str.extract(r'(女士)').isnull() != True
    mlb_in['female'] = mlb_in['female'].astype(int)
    mlb_in['pants'] = mlb_in['name'].str.extract(r'(裤|PANT)').isnull() != True
    mlb_in['pants'] = mlb_in['pants'].astype(int)
    mlb_in['OVERSIZED'] = mlb_in['name'].str.extract(r'(.+OVERSIZED)').isnull() != True
    mlb_in['OVERSIZED'] = mlb_in['OVERSIZED'].astype(int)
 
    mlb_in['DAIMAROO'] = mlb_in['name'].str.extract(r'(DAIMAROO)').isnull() != True
    mlb_in['DAIMAROO'] = mlb_in['DAIMAROO'].astype(int)
    mlb_in['COMFORTABLE'] = mlb_in['name'].str.extract(r'(.+COMFORTABLE)').isnull() != True
    mlb_in['COMFORTABLE'] = mlb_in['COMFORTABLE'].astype(int)

    mlb_in['tmjl'] = mlb_in['name'].str.extract(r'(天猫精灵)').isnull() != True
    mlb_in['tmjl'] = mlb_in['tmjl'].astype(int)
    mlb_in['share'] = mlb_in['name'].str.extract(r'(共用)').isnull() != True
    mlb_in['share'] = mlb_in['share'].astype(int)
    mlb_in['shoe'] = mlb_in['name'].str.extract(r'(鞋)').isnull() != True
    mlb_in['shoe'] = mlb_in['shoe'].astype(int)
    mlb_in['cup'] = mlb_in['name'].str.extract(r'(杯)').isnull() != True
    mlb_in['cup'] = mlb_in['cup'].astype(int)
    mlb_in['textile'] = mlb_in['name'].str.extract(r'(纺织品)').isnull() != True
    mlb_in['textile'] = mlb_in['textile'].astype(int)

    mlb_in['socks'] = mlb_in['name'].str.extract(r'(袜)').isnull() != True
    mlb_in['socks'] = mlb_in['socks'].astype(int)

    mlb_in['dress'] = mlb_in['name'].str.extract(r'(裙)').isnull() != True
    mlb_in['dress'] = mlb_in['dress'].astype(int)
    mlb_in['suit'] = mlb_in['name'].str.extract(r'(套装)').isnull() != True
    mlb_in['suit'] = mlb_in['suit'].astype(int)
    mlb_in['fan'] = mlb_in['name'].str.extract(r'(风扇)').isnull() != True
    mlb_in['fan'] = mlb_in['fan'].astype(int)

data_ppp(mlb_out)

# %%
mlb_out['yearmon'] = mlb_out['date'].str.extract(r'(.{9})')
mlb_out_train = mlb_out.groupby(['yearmon'], as_index=False).sum()

# %%
mlb_out_train.head()
# Out:
#      yearmon        code  quant  top  sp  cap  pack  female  pants  OVERSIZED  \
# 0  2021/2/1   20659348.0  20065  871  51  524   143       7     40          2
# 1  2021/2/10  10561131.0   3567  651  17   31    51       1     39          4
# 2  2021/2/11   4900332.0     65   20  19   16    17       0      4          0
# 3  2021/2/12   5056360.0     66   39  16   17     1       0      6          0
# 4  2021/2/13   5366371.0     70   37  23   24     0       1      6          0
#
#    ...  COMFORTABLE  tmjl  share  shoe  cup  textile  socks  dress  suit  fan
# 0  ...           56     0    114   444    0       13     40      3     0    0
# 1  ...           35     0     59   102    0        4      0      1     0    0
# 2  ...            8     0     28     2    0        1      0      0     0    0
# 3  ...           15     0     32     0    0        0      0      1     0    0
# 4  ...           22     0     46     1    0        1      0      0     0    0
#
# [5 rows x 21 columns]
